# %%
pip install gender_guesser
# Out:
# Requirement already satisfied: gender_guesser in c:\users\pablo\anaconda3\envs\py39\lib\site-packages (0.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

import gender_guesser.detector as gender

import re

# %%
reviews = pd.read_csv('CommentDataset_v1.csv')

# %%
d = gender.Detector(case_sensitive=False)

# %%
def solo_un_nombre(name):
    partes = name.split()
    if len(partes) > 1:
        return partes[0]
    else:
        return name

# %%
reviews['first_name'] = reviews['name'].apply(solo_un_nombre)

reviews['gender'] = reviews['first_name'].apply(d.get_gender)

# %%
reviews = reviews.drop('first_name', axis=1)

# %%
reviews.loc[reviews['name'].isin(['Javier', 'Jesus', 'Jesús', 'João']), 'gender'] = 'male'

reviews.loc[reviews['name'].str.startswith('María'), 'gender'] = 'female'
reviews.loc[reviews['name'].isin(['Glória', 'Mary', 'Rocío', 'Lupe',
                                  'Carol', 'Luz', 'Mary Paule', 'Leslie']), 'gender'] = 'female'

# %%
reviews.head()
# Out:
#            name                                             imagen  \
# 0  Axel Gabriel  https://a0.muscache.com/im/pictures/user/254d7...
# 1         Jakub  https://a0.muscache.com/im/pictures/user/69511...
# 2         Julia  https://a0.muscache.com/im/pictures/user/a1e42...
# 3        Raquel  https://a0.muscache.com/im/pictures/user/36606...
# 4        Thammy  https://a0.muscache.com/im/pictures/user/User-...
#
#                user_id               valoracion  \
# 0  7207102719398425561  Valoración: 5 estrellas
# 1  6677389369241018499   Valoración: 1 estrella
# 2 -2108179332470135818  Valoración: 5 estrellas
# 3 -6435857393761549855  Valoración: 5 estrellas
# 4  3276633884495524409  Valoración: 5 estrellas
#
#                                           comentario            apart_id  \
# 0  Zona perfecta, se ve la playa desde el portal,... -238439061290428255
# 1  El apartamento estaba muy frío, tanto que me e... -238439061290428255
# 2  Tuvimos una estancia agradable, el apartamento... -238439061290428255
# 3  Apartamento estupendo. Bernardo y su mujer son... -238439061290428255
# 4  Piso bonito ,agradable, camas tanto de soltero... -238439061290428255
#
#                 ubicacion   gender
# 0                  España     male
# 1                 Polonia     male
# 2  Lleva 9 años en Airbnb   female
# 3                  España   female
# 4       Barcelona, España  unknown

# %%
def extraer_numeros(texto):
    numeros = re.findall(r'\d+', texto)
    if numeros:
        return int(numeros[0])
    else:
        return None

reviews['rating'] = reviews['valoracion'].apply(extraer_numeros)

# %%
reviews = reviews.drop('valoracion', axis=1)

# %%
reviews.head(10)
# Out:
#            name                                             imagen  \
# 0  Axel Gabriel  https://a0.muscache.com/im/pictures/user/254d7...
# 1         Jakub  https://a0.muscache.com/im/pictures/user/69511...
# 2         Julia  https://a0.muscache.com/im/pictures/user/a1e42...
# 3        Raquel  https://a0.muscache.com/im/pictures/user/36606...
# 4        Thammy  https://a0.muscache.com/im/pictures/user/User-...
# 5      Liudmyla  https://a0.muscache.com/im/pictures/user/User-...
# 6      Patricia  https://a0.muscache.com/im/pictures/user/28443...
# 7        Soraya  https://a0.muscache.com/im/pictures/user/da307...
# 8      Patricia  https://a0.muscache.com/im/pictures/user/e6834...
# 9      Maria C.  https://a0.muscache.com/im/pictures/user/fa780...
#
#                user_id                                         comentario  \
# 0  7207102719398425561  Zona perfecta, se ve la playa desde el portal,...
# 1  6677389369241018499  El apartamento estaba muy frío, tanto que me e...
# 2 -2108179332470135818  Tuvimos una estancia agradable, el apartamento...
# 3 -6435857393761549855  Apartamento estupendo. Bernardo y su mujer son...
# 4  3276633884495524409  Piso bonito ,agradable, camas tanto de soltero...
# 5 -8963005761064894402  Gracias a Bernando por responder rápidamente a...
# 6 -1778062113197377075                       muy limpio y buena ubicación
# 7  4584548507691434122  apartamento muy bien ubicado y limpio!!! buena...
# 8 -3302352277475470840  El apartamento muy cómodo y muy completo. Con ...
# 9  8631865942084326397          Estancia agradable a destacar la limpieza
#
#              apart_id               ubicacion   gender  rating
# 0 -238439061290428255                  España     male       5
# 1 -238439061290428255                 Polonia     male       1
# 2 -238439061290428255  Lleva 9 años en Airbnb   female       5
# 3 -238439061290428255                  España   female       5
# 4 -238439061290428255       Barcelona, España  unknown       5
# 5 -238439061290428255                  España  unknown       5
# 6 -238439061290428255       Sídney, Australia   female       5
# 7 -238439061290428255                  España   female       5
# 8 -238439061290428255                  España   female       4
# 9 -238439061290428255                  España   female       5

# %%
reviews.to_csv('CommentDataset_cleaned_v1.csv', index=False)
